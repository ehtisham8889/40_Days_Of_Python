# %% [markdown]
# ## Simple Code to Run Custom Data

# %%
import seaborn as sns
import matplotlib.pyplot as py
import pandas as pd

# Read Your Custom Data
# Note Your Custom Data file should be in the same directory

chilla = pd.read_csv("Chilla_data.csv") 
chilla.head()

sns.barplot(x="What are you?", y="Age (years)-Float/Int", hue="Gender", data= chilla)
# Out:
# <AxesSubplot:xlabel='What are you?', ylabel='Age (years)-Float/Int'>
